# %%
from pymongo import MongoClient
from gridfs import GridFSBucket
import io
from bson import ObjectId

from dotenv import load_dotenv
load_dotenv()

# Connect to MongoDB
client = MongoClient()
db = client['aieta']

# Create GridFS bucket
bucket = GridFSBucket(db)

# Replace with your ObjectId from MongoDB
file_id = "69096aa68a7f5546967fa59"

# Read file into memory
with io.BytesIO() as audio_stream:
    bucket.download_to_stream(ObjectId(file_id), audio_stream)
    audio_data = audio_stream.getvalue()

# Save locally as MP3
with open("output.mp3", "wb") as f:
    f.write(audio_data)
print("✅ Saved output.mp3")
# Out:
# ---------------------------------------------------------------------------
# InvalidId                                 Traceback (most recent call last)
# Cell In[4], line 21
#      19 # Read file into memory
#      20 with io.BytesIO() as audio_stream:
# ---> 21     bucket.download_to_stream(ObjectId(file_id), audio_stream)
#      22     audio_data = audio_stream.getvalue()
#      24 # Save locally as MP3
#
# File ~/miniconda3/envs/rupadi/lib/python3.10/site-packages/bson/objectid.py:105, in ObjectId.__init__(self, oid)
#     103     self.__id = oid
#     104 else:
# --> 105     self.__validate(oid)
#
# File ~/miniconda3/envs/rupadi/lib/python3.10/site-packages/bson/objectid.py:193, in ObjectId.__validate(self, oid)
#     191             _raise_invalid_id(oid)
#     192     else:
# --> 193         _raise_invalid_id(oid)
#     194 else:
#     195     raise TypeError(f"id must be an instance of (bytes, str, ObjectId), not {type(oid)}")
#
# ...

# %%
from bson import ObjectId
print(len("69096aa68a7f5546967fa59"))  # should print 24
ObjectId("69096aa68a7f5546967fa59")    # should not raise an error
# Out:
# 23
# ---------------------------------------------------------------------------
# InvalidId                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 from bson import ObjectId
#       2 print(len("69096aa68a7f5546967fa59"))  # should print 24
# ----> 3 ObjectId("69096aa68a7f5546967fa59")    # should not raise an error
#
# File ~/miniconda3/envs/rupadi/lib/python3.10/site-packages/bson/objectid.py:105, in ObjectId.__init__(self, oid)
#     103     self.__id = oid
#     104 else:
# --> 105     self.__validate(oid)
#
# File ~/miniconda3/envs/rupadi/lib/python3.10/site-packages/bson/objectid.py:193, in ObjectId.__validate(self, oid)
#     191             _raise_invalid_id(oid)
#     192     else:
# --> 193         _raise_invalid_id(oid)
#     194 else:
#     195     raise TypeError(f"id must be an instance of (bytes, str, ObjectId), not {type(oid)}")
#
# ...

# %%
db.fs.files.find_one()
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 db.fs.files.find_one()
#
# File ~/miniconda3/envs/rupadi/lib/python3.10/site-packages/pymongo/synchronous/collection.py:1755, in Collection.find_one(self, filter, *args, **kwargs)
#    1753     filter = {"_id": filter}
#    1754 cursor = self.find(filter, *args, **kwargs)
# -> 1755 for result in cursor.limit(-1):
#    1756     return result
#    1757 return None
#
# File ~/miniconda3/envs/rupadi/lib/python3.10/site-packages/pymongo/synchronous/cursor.py:1289, in Cursor.__next__(self)
#    1288 def __next__(self) -> _DocumentType:
# -> 1289     return self.next()
#
# File ~/miniconda3/envs/rupadi/lib/python3.10/site-packages/pymongo/synchronous/cursor.py:1265, in Cursor.next(self)
#    1263 if self._empty:
#    1264     raise StopIteration
# -> 1265 if len(self._data) or self._refresh():
# ...
